# %%
# %matplotlib inline
from matplotlib import pyplot as plt
import numpy as np
np.set_printoptions(threshold=np.inf)
import math
import westpa.cli.tools.w_ipa as w_ipa
from westpa.analysis import BasicMDTrajectory
from scipy import stats
w = w_ipa.WIPI()

# At startup, it will load or run the analysis schemes specified in the configuration file (typically west.cfg)
w.main()
w.interface = 'matplotlib'
# Out:
# Welcome to w_ipa (WESTPA Interactive Python Analysis) v. 1.0B!
# Run w.introduction for a more thorough introduction, or w.help to see a list of options.
# Running analysis & loading files.
# Reanalyzing file direct.h5 for scheme TEST.
# Initializing...
# Tracing trajectories...
# Calculating Rate Evolution...
# Calculating Conditional Flux Evolution...
# Calculating Target Flux Evolution...
# Calculating Rate Evolution...
# Calculating Conditional Flux Evolution...
# Calculating Target Flux Evolution...
# Calculating Color Probability Evolution...
# Calculating State Probability Evolution...
# Calculating Color Probability Evolution...
# Calculating State Probability Evolution...
#
# Complete!
# Setting iteration to iter 1350.
# Your current scheme, system and iteration are : TEST, /home/praveen/Documents/Chignolin_WE/Contact/Trial12/New3_updated_tstate, 1350

# %%
total_iteration =  1350

dt = 1 #frequency at which pcoord data is saved

sink = 0.28 #target state

time_unit = 'ps'

#-----------------------------------------------------------------------------#
#--NO NEED TO MODIFY ANYTHING BELOW UNLESS YOU WANT TO CHANGE THE ALGORITHM---#
#-----------------------------------------------------------------------------#
it = np.zeros(total_iteration) #array to store flux data
time = np.zeros(total_iteration) #array to store time data

force_eval = 0.0

for i in range(total_iteration):
    #find out which iteration you are in
    w.iteration = i+1
    
    #get an array of all the segments you have in this iteration
    l = w.current.pcoord
    
    #get the weight of all the segments in this iteration
    wts = w.current.weights
    
    #size of each segment
    tau = len(l[0])
    print(tau)
    
    #calculate total computational time spent (size * number of segment * time unit)
    force_eval += (tau-1)*len(l)*dt
    print('total simulation time = ', force_eval, time_unit)
    
    #run loop to see which trajectories crossed the sink
    for j in range(len(l)):
        if l[j][0] > sink and l[j][tau-1] <= sink:
            #add its weight to the flux array
            it[i] += wts[j]
            
     
    
    try: 
        time[i] = (i/sum(it))*(tau-1)*dt #compute first passage time as time/flux
    except: 
        time[i] = 0.0 #take care of iterations when no segment reached the sink
# Out:
# Setting iteration to iter 1.
# 11
# total simulation time =  40.0 ps
# Setting iteration to iter 2.
# 11
# total simulation time =  160.0 ps
# Setting iteration to iter 3.
# 11
# total simulation time =  280.0 ps
# Setting iteration to iter 4.
# 11
# total simulation time =  400.0 ps
# Setting iteration to iter 5.
# 11
# total simulation time =  520.0 ps
# Setting iteration to iter 6.
# 11
# total simulation time =  600.0 ps
# Setting iteration to iter 7.
# 11
# total simulation time =  800.0 ps
# Setting iteration to iter 8.
# 11
# total simulation time =  1040.0 ps
# Setting iteration to iter 9.
# 11
# total simulation time =  1320.0 ps
# Setting iteration to iter 10.
# 11
# total simulation time =  1600.0 ps
# Setting iteration to iter 11.
# 11
# total simulation time =  1880.0 ps
# Setting iteration to iter 12.
# 11
# total simulation time =  2080.0 ps
# Setting iteration to iter 13.
# 11
# total simulation time =  2280.0 ps
# Setting iteration to iter 14.
# 11
# total simulation time =  2560.0 ps
# Setting iteration to iter 15.
# 11
# total simulation time =  2840.0 ps
# Setting iteration to iter 16.
# 11
# total simulation time =  3160.0 ps
# Setting iteration to iter 17.
# 11
# total simulation time =  3400.0 ps
# Setting iteration to iter 18.
# 11
# total simulation time =  3600.0 ps
# Setting iteration to iter 19.
# 11
# total simulation time =  3880.0 ps
# Setting iteration to iter 20.
# 11
# total simulation time =  4120.0 ps
# Setting iteration to iter 21.
# 11
# total simulation time =  4400.0 ps
# Setting iteration to iter 22.
# 11
# total simulation time =  4720.0 ps
# Setting iteration to iter 23.
# 11
# total simulation time =  5000.0 ps
# Setting iteration to iter 24.
# 11
# total simulation time =  5160.0 ps
# Setting iteration to iter 25.
# 11
# total simulation time =  5320.0 ps
# Setting iteration to iter 26.
# 11
# total simulation time =  5400.0 ps
# Setting iteration to iter 27.
# 11
# total simulation time =  5560.0 ps
# Setting iteration to iter 28.
# 11
# total simulation time =  5640.0 ps
# Setting iteration to iter 29.
# 11
# total simulation time =  5720.0 ps
# Setting iteration to iter 30.
# 11
# total simulation time =  5840.0 ps
# Setting iteration to iter 31.
# 11
# total simulation time =  5920.0 ps
# Setting iteration to iter 32.
# 11
# total simulation time =  6040.0 ps
# Setting iteration to iter 33.
# 11
# total simulation time =  6120.0 ps
# Setting iteration to iter 34.
# 11
# total simulation time =  6280.0 ps
# Setting iteration to iter 35.
# 11
# total simulation time =  6400.0 ps
# Setting iteration to iter 36.
# 11
# total simulation time =  6600.0 ps
# Setting iteration to iter 37.
# 11
# total simulation time =  6840.0 ps
# Setting iteration to iter 38.
# 11
# total simulation time =  7040.0 ps
# Setting iteration to iter 39.
# 11
# total simulation time =  7240.0 ps
# Setting iteration to iter 40.
# 11
# total simulation time =  7480.0 ps
# Setting iteration to iter 41.
# 11
# total simulation time =  7680.0 ps
# Setting iteration to iter 42.
# 11
# total simulation time =  7960.0 ps
# Setting iteration to iter 43.
# 11
# total simulation time =  8240.0 ps
# Setting iteration to iter 44.
# 11
# total simulation time =  8520.0 ps
# Setting iteration to iter 45.
# 11
# total simulation time =  8800.0 ps
# Setting iteration to iter 46.
# 11
# total simulation time =  9040.0 ps
# Setting iteration to iter 47.
# 11
# total simulation time =  9240.0 ps
# Setting iteration to iter 48.
# 11
# total simulation time =  9480.0 ps
# Setting iteration to iter 49.
# 11
# total simulation time =  9800.0 ps
# Setting iteration to iter 50.
# 11
# total simulation time =  10200.0 ps
# Setting iteration to iter 51.
# 11
# total simulation time =  10600.0 ps
# Setting iteration to iter 52.
# 11
# total simulation time =  11040.0 ps
# Setting iteration to iter 53.
# 11
# total simulation time =  11480.0 ps
# Setting iteration to iter 54.
# 11
# total simulation time =  11920.0 ps
# Setting iteration to iter 55.
# 11
# total simulation time =  12320.0 ps
# Setting iteration to iter 56.
# 11
# total simulation time =  12760.0 ps
# Setting iteration to iter 57.
# 11
# total simulation time =  13240.0 ps
# Setting iteration to iter 58.
# 11
# total simulation time =  13720.0 ps
# Setting iteration to iter 59.
# 11
# total simulation time =  14240.0 ps
# Setting iteration to iter 60.
# 11
# total simulation time =  14720.0 ps
# Setting iteration to iter 61.
# 11
# total simulation time =  15240.0 ps
# Setting iteration to iter 62.
# 11
# total simulation time =  15720.0 ps
# Setting iteration to iter 63.
# 11
# total simulation time =  16280.0 ps
# Setting iteration to iter 64.
# 11
# total simulation time =  16800.0 ps
# Setting iteration to iter 65.
# 11
# total simulation time =  17320.0 ps
# Setting iteration to iter 66.
# 11
# total simulation time =  17840.0 ps
# Setting iteration to iter 67.
# 11
# total simulation time =  18440.0 ps
# Setting iteration to iter 68.
# 11
# total simulation time =  19040.0 ps
# Setting iteration to iter 69.
# 11
# total simulation time =  19600.0 ps
# Setting iteration to iter 70.
# 11
# total simulation time =  20200.0 ps
# Setting iteration to iter 71.
# 11
# total simulation time =  20840.0 ps
# Setting iteration to iter 72.
# 11
# total simulation time =  21480.0 ps
# Setting iteration to iter 73.
# 11
# total simulation time =  22080.0 ps
# Setting iteration to iter 74.
# 11
# total simulation time =  22720.0 ps
# Setting iteration to iter 75.
# 11
# total simulation time =  23360.0 ps
# Setting iteration to iter 76.
# 11
# total simulation time =  23960.0 ps
# Setting iteration to iter 77.
# 11
# total simulation time =  24560.0 ps
# Setting iteration to iter 78.
# 11
# total simulation time =  25200.0 ps
# Setting iteration to iter 79.
# 11
# total simulation time =  25840.0 ps
# Setting iteration to iter 80.
# 11
# total simulation time =  26400.0 ps
# Setting iteration to iter 81.
# 11
# total simulation time =  27000.0 ps
# Setting iteration to iter 82.
# 11
# total simulation time =  27600.0 ps
# Setting iteration to iter 83.
# 11
# total simulation time =  28240.0 ps
# Setting iteration to iter 84.
# 11
# total simulation time =  28880.0 ps
# Setting iteration to iter 85.
# 11
# total simulation time =  29440.0 ps
# Setting iteration to iter 86.
# 11
# total simulation time =  30000.0 ps
# Setting iteration to iter 87.
# 11
# total simulation time =  30640.0 ps
# Setting iteration to iter 88.
# 11
# total simulation time =  31280.0 ps
# Setting iteration to iter 89.
# 11
# total simulation time =  31920.0 ps
# Setting iteration to iter 90.
# 11
# total simulation time =  32560.0 ps
# Setting iteration to iter 91.
# 11
# total simulation time =  33160.0 ps
# Setting iteration to iter 92.
# 11
# total simulation time =  33800.0 ps
# Setting iteration to iter 93.
# 11
# total simulation time =  34440.0 ps
# Setting iteration to iter 94.
# 11
# total simulation time =  35000.0 ps
# Setting iteration to iter 95.
# 11
# total simulation time =  35600.0 ps
# Setting iteration to iter 96.
# 11
# total simulation time =  36200.0 ps
# Setting iteration to iter 97.
# 11
# total simulation time =  36800.0 ps
# Setting iteration to iter 98.
# 11
# total simulation time =  37360.0 ps
# Setting iteration to iter 99.
# 11
# total simulation time =  37920.0 ps
# Setting iteration to iter 100.
# 11
# total simulation time =  38480.0 ps
# Setting iteration to iter 101.
# 11
# total simulation time =  39080.0 ps
# Setting iteration to iter 102.
# 11
# total simulation time =  39680.0 ps
# Setting iteration to iter 103.
# 11
# total simulation time =  40280.0 ps
# Setting iteration to iter 104.
# 11
# total simulation time =  40880.0 ps
# Setting iteration to iter 105.
# 11
# total simulation time =  41440.0 ps
# Setting iteration to iter 106.
# 11
# total simulation time =  42000.0 ps
# Setting iteration to iter 107.
# 11
# total simulation time =  42520.0 ps
# Setting iteration to iter 108.
# 11
# total simulation time =  43120.0 ps
# Setting iteration to iter 109.
# 11
# total simulation time =  43760.0 ps
# Setting iteration to iter 110.
# 11
# total simulation time =  44320.0 ps
# Setting iteration to iter 111.
# 11
# total simulation time =  44920.0 ps
# Setting iteration to iter 112.
# 11
# total simulation time =  45520.0 ps
# Setting iteration to iter 113.
# 11
# total simulation time =  46160.0 ps
# Setting iteration to iter 114.
# 11
# total simulation time =  46800.0 ps
# Setting iteration to iter 115.
# 11
# total simulation time =  47400.0 ps
# Setting iteration to iter 116.
# 11
# total simulation time =  48000.0 ps
# Setting iteration to iter 117.
# 11
# total simulation time =  48600.0 ps
# Setting iteration to iter 118.
# 11
# total simulation time =  49200.0 ps
# Setting iteration to iter 119.
# 11
# total simulation time =  49800.0 ps
# Setting iteration to iter 120.
# 11
# total simulation time =  50440.0 ps
# Setting iteration to iter 121.
# 11
# total simulation time =  51080.0 ps
# Setting iteration to iter 122.
# 11
# total simulation time =  51720.0 ps
# Setting iteration to iter 123.
# 11
# total simulation time =  52280.0 ps
# Setting iteration to iter 124.
# 11
# total simulation time =  52840.0 ps
# Setting iteration to iter 125.
# 11
# total simulation time =  53440.0 ps
# Setting iteration to iter 126.
# 11
# total simulation time =  54040.0 ps
# Setting iteration to iter 127.
# 11
# total simulation time =  54600.0 ps
# Setting iteration to iter 128.
# 11
# total simulation time =  55240.0 ps
# Setting iteration to iter 129.
# 11
# total simulation time =  55840.0 ps
# Setting iteration to iter 130.
# 11
# total simulation time =  56440.0 ps
# Setting iteration to iter 131.
# 11
# total simulation time =  57040.0 ps
# Setting iteration to iter 132.
# 11
# total simulation time =  57680.0 ps
# Setting iteration to iter 133.
# 11
# total simulation time =  58360.0 ps
# Setting iteration to iter 134.
# 11
# total simulation time =  58960.0 ps
# Setting iteration to iter 135.
# 11
# total simulation time =  59600.0 ps
# Setting iteration to iter 136.
# 11
# total simulation time =  60160.0 ps
# Setting iteration to iter 137.
# 11
# total simulation time =  60720.0 ps
# Setting iteration to iter 138.
# 11
# total simulation time =  61320.0 ps
# Setting iteration to iter 139.
# 11
# total simulation time =  61920.0 ps
# Setting iteration to iter 140.
# 11
# total simulation time =  62440.0 ps
# Setting iteration to iter 141.
# 11
# total simulation time =  63040.0 ps
# Setting iteration to iter 142.
# 11
# total simulation time =  63640.0 ps
# Setting iteration to iter 143.
# 11
# total simulation time =  64200.0 ps
# Setting iteration to iter 144.
# 11
# total simulation time =  64800.0 ps
# Setting iteration to iter 145.
# 11
# total simulation time =  65400.0 ps
# Setting iteration to iter 146.
# 11
# total simulation time =  66000.0 ps
# Setting iteration to iter 147.
# 11
# total simulation time =  66600.0 ps
# Setting iteration to iter 148.
# 11
# total simulation time =  67160.0 ps
# Setting iteration to iter 149.
# 11
# total simulation time =  67680.0 ps
# Setting iteration to iter 150.
# 11
# total simulation time =  68200.0 ps
# Setting iteration to iter 151.
# 11
# total simulation time =  68760.0 ps
# Setting iteration to iter 152.
# 11
# total simulation time =  69360.0 ps
# Setting iteration to iter 153.
# 11
# total simulation time =  69920.0 ps
# Setting iteration to iter 154.
# 11
# total simulation time =  70480.0 ps
# Setting iteration to iter 155.
# 11
# total simulation time =  71080.0 ps
# Setting iteration to iter 156.
# 11
# total simulation time =  71680.0 ps
# Setting iteration to iter 157.
# 11
# total simulation time =  72240.0 ps
# Setting iteration to iter 158.
# 11
# total simulation time =  72800.0 ps
# Setting iteration to iter 159.
# 11
# total simulation time =  73480.0 ps
# Setting iteration to iter 160.
# 11
# total simulation time =  74080.0 ps
# Setting iteration to iter 161.
# 11
# total simulation time =  74720.0 ps
# Setting iteration to iter 162.
# 11
# total simulation time =  75320.0 ps
# Setting iteration to iter 163.
# 11
# total simulation time =  75960.0 ps
# Setting iteration to iter 164.
# 11
# total simulation time =  76520.0 ps
# Setting iteration to iter 165.
# 11
# total simulation time =  77120.0 ps
# Setting iteration to iter 166.
# 11
# total simulation time =  77720.0 ps
# Setting iteration to iter 167.
# 11
# total simulation time =  78280.0 ps
# Setting iteration to iter 168.
# 11
# total simulation time =  78880.0 ps
# Setting iteration to iter 169.
# 11
# total simulation time =  79440.0 ps
# Setting iteration to iter 170.
# 11
# total simulation time =  80080.0 ps
# Setting iteration to iter 171.
# 11
# total simulation time =  80680.0 ps
# Setting iteration to iter 172.
# 11
# total simulation time =  81320.0 ps
# Setting iteration to iter 173.
# 11
# total simulation time =  81880.0 ps
# Setting iteration to iter 174.
# 11
# total simulation time =  82480.0 ps
# Setting iteration to iter 175.
# 11
# total simulation time =  83000.0 ps
# Setting iteration to iter 176.
# 11
# total simulation time =  83560.0 ps
# Setting iteration to iter 177.
# 11
# total simulation time =  84200.0 ps
# Setting iteration to iter 178.
# 11
# total simulation time =  84800.0 ps
# Setting iteration to iter 179.
# 11
# total simulation time =  85320.0 ps
# Setting iteration to iter 180.
# 11
# total simulation time =  85840.0 ps
# Setting iteration to iter 181.
# 11
# total simulation time =  86440.0 ps
# Setting iteration to iter 182.
# 11
# total simulation time =  87120.0 ps
# Setting iteration to iter 183.
# 11
# total simulation time =  87680.0 ps
# Setting iteration to iter 184.
# 11
# total simulation time =  88240.0 ps
# Setting iteration to iter 185.
# 11
# total simulation time =  88920.0 ps
# Setting iteration to iter 186.
# 11
# total simulation time =  89600.0 ps
# Setting iteration to iter 187.
# 11
# total simulation time =  90240.0 ps
# Setting iteration to iter 188.
# 11
# total simulation time =  90880.0 ps
# Setting iteration to iter 189.
# 11
# total simulation time =  91480.0 ps
# Setting iteration to iter 190.
# 11
# total simulation time =  92160.0 ps
# Setting iteration to iter 191.
# 11
# total simulation time =  92800.0 ps
# Setting iteration to iter 192.
# 11
# total simulation time =  93440.0 ps
# Setting iteration to iter 193.
# 11
# total simulation time =  94040.0 ps
# Setting iteration to iter 194.
# 11
# total simulation time =  94640.0 ps
# Setting iteration to iter 195.
# 11
# total simulation time =  95240.0 ps
# Setting iteration to iter 196.
# 11
# total simulation time =  95840.0 ps
# Setting iteration to iter 197.
# 11
# total simulation time =  96400.0 ps
# Setting iteration to iter 198.
# 11
# total simulation time =  97040.0 ps
# Setting iteration to iter 199.
# 11
# total simulation time =  97680.0 ps
# Setting iteration to iter 200.
# 11
# total simulation time =  98320.0 ps
# Setting iteration to iter 201.
# 11
# total simulation time =  98960.0 ps
# Setting iteration to iter 202.
# 11
# total simulation time =  99640.0 ps
# Setting iteration to iter 203.
# 11
# total simulation time =  100280.0 ps
# Setting iteration to iter 204.
# 11
# total simulation time =  100920.0 ps
# Setting iteration to iter 205.
# 11
# total simulation time =  101560.0 ps
# Setting iteration to iter 206.
# 11
# total simulation time =  102240.0 ps
# Setting iteration to iter 207.
# 11
# total simulation time =  102880.0 ps
# Setting iteration to iter 208.
# 11
# total simulation time =  103480.0 ps
# Setting iteration to iter 209.
# 11
# total simulation time =  104080.0 ps
# Setting iteration to iter 210.
# 11
# total simulation time =  104680.0 ps
# Setting iteration to iter 211.
# 11
# total simulation time =  105320.0 ps
# Setting iteration to iter 212.
# 11
# total simulation time =  105960.0 ps
# Setting iteration to iter 213.
# 11
# total simulation time =  106560.0 ps
# Setting iteration to iter 214.
# 11
# total simulation time =  107160.0 ps
# Setting iteration to iter 215.
# 11
# total simulation time =  107800.0 ps
# Setting iteration to iter 216.
# 11
# total simulation time =  108440.0 ps
# Setting iteration to iter 217.
# 11
# total simulation time =  109040.0 ps
# Setting iteration to iter 218.
# 11
# total simulation time =  109680.0 ps
# Setting iteration to iter 219.
# 11
# total simulation time =  110320.0 ps
# Setting iteration to iter 220.
# 11
# total simulation time =  111000.0 ps
# Setting iteration to iter 221.
# 11
# total simulation time =  111640.0 ps
# Setting iteration to iter 222.
# 11
# total simulation time =  112320.0 ps
# Setting iteration to iter 223.
# 11
# total simulation time =  112960.0 ps
# Setting iteration to iter 224.
# 11
# total simulation time =  113600.0 ps
# Setting iteration to iter 225.
# 11
# total simulation time =  114240.0 ps
# Setting iteration to iter 226.
# 11
# total simulation time =  114840.0 ps
# Setting iteration to iter 227.
# 11
# total simulation time =  115480.0 ps
# Setting iteration to iter 228.
# 11
# total simulation time =  116120.0 ps
# Setting iteration to iter 229.
# 11
# total simulation time =  116760.0 ps
# Setting iteration to iter 230.
# 11
# total simulation time =  117400.0 ps
# Setting iteration to iter 231.
# 11
# total simulation time =  118000.0 ps
# Setting iteration to iter 232.
# 11
# total simulation time =  118640.0 ps
# Setting iteration to iter 233.
# 11
# total simulation time =  119160.0 ps
# Setting iteration to iter 234.
# 11
# total simulation time =  119720.0 ps
# Setting iteration to iter 235.
# 11
# total simulation time =  120400.0 ps
# Setting iteration to iter 236.
# 11
# total simulation time =  121040.0 ps
# Setting iteration to iter 237.
# 11
# total simulation time =  121680.0 ps
# Setting iteration to iter 238.
# 11
# total simulation time =  122360.0 ps
# Setting iteration to iter 239.
# 11
# total simulation time =  123000.0 ps
# Setting iteration to iter 240.
# 11
# total simulation time =  123480.0 ps
# Setting iteration to iter 241.
# 11
# total simulation time =  124040.0 ps
# Setting iteration to iter 242.
# 11
# total simulation time =  124720.0 ps
# Setting iteration to iter 243.
# 11
# total simulation time =  125360.0 ps
# Setting iteration to iter 244.
# 11
# total simulation time =  126000.0 ps
# Setting iteration to iter 245.
# 11
# total simulation time =  126600.0 ps
# Setting iteration to iter 246.
# 11
# total simulation time =  127200.0 ps
# Setting iteration to iter 247.
# 11
# total simulation time =  127760.0 ps
# Setting iteration to iter 248.
# 11
# total simulation time =  128360.0 ps
# Setting iteration to iter 249.
# 11
# total simulation time =  129040.0 ps
# Setting iteration to iter 250.
# 11
# total simulation time =  129680.0 ps
# Setting iteration to iter 251.
# 11
# total simulation time =  130360.0 ps
# Setting iteration to iter 252.
# 11
# total simulation time =  130960.0 ps
# Setting iteration to iter 253.
# 11
# total simulation time =  131560.0 ps
# Setting iteration to iter 254.
# 11
# total simulation time =  132200.0 ps
# Setting iteration to iter 255.
# 11
# total simulation time =  132800.0 ps
# Setting iteration to iter 256.
# 11
# total simulation time =  133400.0 ps
# Setting iteration to iter 257.
# 11
# total simulation time =  134000.0 ps
# Setting iteration to iter 258.
# 11
# total simulation time =  134640.0 ps
# Setting iteration to iter 259.
# 11
# total simulation time =  135280.0 ps
# Setting iteration to iter 260.
# 11
# total simulation time =  135840.0 ps
# Setting iteration to iter 261.
# 11
# total simulation time =  136440.0 ps
# Setting iteration to iter 262.
# 11
# total simulation time =  137080.0 ps
# Setting iteration to iter 263.
# 11
# total simulation time =  137760.0 ps
# Setting iteration to iter 264.
# 11
# total simulation time =  138400.0 ps
# Setting iteration to iter 265.
# 11
# total simulation time =  139000.0 ps
# Setting iteration to iter 266.
# 11
# total simulation time =  139600.0 ps
# Setting iteration to iter 267.
# 11
# total simulation time =  140280.0 ps
# Setting iteration to iter 268.
# 11
# total simulation time =  140920.0 ps
# Setting iteration to iter 269.
# 11
# total simulation time =  141560.0 ps
# Setting iteration to iter 270.
# 11
# total simulation time =  142120.0 ps
# Setting iteration to iter 271.
# 11
# total simulation time =  142640.0 ps
# Setting iteration to iter 272.
# 11
# total simulation time =  143200.0 ps
# Setting iteration to iter 273.
# 11
# total simulation time =  143760.0 ps
# Setting iteration to iter 274.
# 11
# total simulation time =  144360.0 ps
# Setting iteration to iter 275.
# 11
# total simulation time =  144880.0 ps
# Setting iteration to iter 276.
# 11
# total simulation time =  145400.0 ps
# Setting iteration to iter 277.
# 11
# total simulation time =  145920.0 ps
# Setting iteration to iter 278.
# 11
# total simulation time =  146480.0 ps
# Setting iteration to iter 279.
# 11
# total simulation time =  147040.0 ps
# Setting iteration to iter 280.
# 11
# total simulation time =  147600.0 ps
# Setting iteration to iter 281.
# 11
# total simulation time =  148240.0 ps
# Setting iteration to iter 282.
# 11
# total simulation time =  148840.0 ps
# Setting iteration to iter 283.
# 11
# total simulation time =  149360.0 ps
# Setting iteration to iter 284.
# 11
# total simulation time =  150000.0 ps
# Setting iteration to iter 285.
# 11
# total simulation time =  150640.0 ps
# Setting iteration to iter 286.
# 11
# total simulation time =  151200.0 ps
# Setting iteration to iter 287.
# 11
# total simulation time =  151800.0 ps
# Setting iteration to iter 288.
# 11
# total simulation time =  152400.0 ps
# Setting iteration to iter 289.
# 11
# total simulation time =  153040.0 ps
# Setting iteration to iter 290.
# 11
# total simulation time =  153720.0 ps
# Setting iteration to iter 291.
# 11
# total simulation time =  154360.0 ps
# Setting iteration to iter 292.
# 11
# total simulation time =  155000.0 ps
# Setting iteration to iter 293.
# 11
# total simulation time =  155600.0 ps
# Setting iteration to iter 294.
# 11
# total simulation time =  156240.0 ps
# Setting iteration to iter 295.
# 11
# total simulation time =  156800.0 ps
# Setting iteration to iter 296.
# 11
# total simulation time =  157360.0 ps
# Setting iteration to iter 297.
# 11
# total simulation time =  157920.0 ps
# Setting iteration to iter 298.
# 11
# total simulation time =  158480.0 ps
# Setting iteration to iter 299.
# 11
# total simulation time =  159040.0 ps
# Setting iteration to iter 300.
# 11
# total simulation time =  159600.0 ps
# Setting iteration to iter 301.
# 11
# total simulation time =  160120.0 ps
# Setting iteration to iter 302.
# 11
# total simulation time =  160720.0 ps
# Setting iteration to iter 303.
# 11
# total simulation time =  161360.0 ps
# Setting iteration to iter 304.
# 11
# total simulation time =  162000.0 ps
# Setting iteration to iter 305.
# 11
# total simulation time =  162560.0 ps
# Setting iteration to iter 306.
# 11
# total simulation time =  163120.0 ps
# Setting iteration to iter 307.
# 11
# total simulation time =  163760.0 ps
# Setting iteration to iter 308.
# 11
# total simulation time =  164320.0 ps
# Setting iteration to iter 309.
# 11
# total simulation time =  164840.0 ps
# Setting iteration to iter 310.
# 11
# total simulation time =  165400.0 ps
# Setting iteration to iter 311.
# 11
# total simulation time =  165920.0 ps
# Setting iteration to iter 312.
# 11
# total simulation time =  166440.0 ps
# Setting iteration to iter 313.
# 11
# total simulation time =  167000.0 ps
# Setting iteration to iter 314.
# 11
# total simulation time =  167560.0 ps
# Setting iteration to iter 315.
# 11
# total simulation time =  168120.0 ps
# Setting iteration to iter 316.
# 11
# total simulation time =  168720.0 ps
# Setting iteration to iter 317.
# 11
# total simulation time =  169320.0 ps
# Setting iteration to iter 318.
# 11
# total simulation time =  169840.0 ps
# Setting iteration to iter 319.
# 11
# total simulation time =  170400.0 ps
# Setting iteration to iter 320.
# 11
# total simulation time =  171000.0 ps
# Setting iteration to iter 321.
# 11
# total simulation time =  171600.0 ps
# Setting iteration to iter 322.
# 11
# total simulation time =  172120.0 ps
# Setting iteration to iter 323.
# 11
# total simulation time =  172720.0 ps
# Setting iteration to iter 324.
# 11
# total simulation time =  173320.0 ps
# Setting iteration to iter 325.
# 11
# total simulation time =  173960.0 ps
# Setting iteration to iter 326.
# 11
# total simulation time =  174520.0 ps
# Setting iteration to iter 327.
# 11
# total simulation time =  175120.0 ps
# Setting iteration to iter 328.
# 11
# total simulation time =  175680.0 ps
# Setting iteration to iter 329.
# 11
# total simulation time =  176280.0 ps
# Setting iteration to iter 330.
# 11
# total simulation time =  176880.0 ps
# Setting iteration to iter 331.
# 11
# total simulation time =  177480.0 ps
# Setting iteration to iter 332.
# 11
# total simulation time =  178120.0 ps
# Setting iteration to iter 333.
# 11
# total simulation time =  178680.0 ps
# Setting iteration to iter 334.
# 11
# total simulation time =  179240.0 ps
# Setting iteration to iter 335.
# 11
# total simulation time =  179840.0 ps
# Setting iteration to iter 336.
# 11
# total simulation time =  180440.0 ps
# Setting iteration to iter 337.
# 11
# total simulation time =  181080.0 ps
# Setting iteration to iter 338.
# 11
# total simulation time =  181720.0 ps
# Setting iteration to iter 339.
# 11
# total simulation time =  182320.0 ps
# Setting iteration to iter 340.
# 11
# total simulation time =  182880.0 ps
# Setting iteration to iter 341.
# 11
# total simulation time =  183400.0 ps
# Setting iteration to iter 342.
# 11
# total simulation time =  183960.0 ps
# Setting iteration to iter 343.
# 11
# total simulation time =  184480.0 ps
# Setting iteration to iter 344.
# 11
# total simulation time =  185080.0 ps
# Setting iteration to iter 345.
# 11
# total simulation time =  185640.0 ps
# Setting iteration to iter 346.
# 11
# total simulation time =  186200.0 ps
# Setting iteration to iter 347.
# 11
# total simulation time =  186800.0 ps
# Setting iteration to iter 348.
# 11
# total simulation time =  187400.0 ps
# Setting iteration to iter 349.
# 11
# total simulation time =  187960.0 ps
# Setting iteration to iter 350.
# 11
# total simulation time =  188560.0 ps
# Setting iteration to iter 351.
# 11
# total simulation time =  189120.0 ps
# Setting iteration to iter 352.
# 11
# total simulation time =  189680.0 ps
# Setting iteration to iter 353.
# 11
# total simulation time =  190280.0 ps
# Setting iteration to iter 354.
# 11
# total simulation time =  190840.0 ps
# Setting iteration to iter 355.
# 11
# total simulation time =  191480.0 ps
# Setting iteration to iter 356.
# 11
# total simulation time =  192080.0 ps
# Setting iteration to iter 357.
# 11
# total simulation time =  192720.0 ps
# Setting iteration to iter 358.
# 11
# total simulation time =  193320.0 ps
# Setting iteration to iter 359.
# 11
# total simulation time =  193920.0 ps
# Setting iteration to iter 360.
# 11
# total simulation time =  194480.0 ps
# Setting iteration to iter 361.
# 11
# total simulation time =  195040.0 ps
# Setting iteration to iter 362.
# 11
# total simulation time =  195560.0 ps
# Setting iteration to iter 363.
# 11
# total simulation time =  196160.0 ps
# Setting iteration to iter 364.
# 11
# total simulation time =  196720.0 ps
# Setting iteration to iter 365.
# 11
# total simulation time =  197280.0 ps
# Setting iteration to iter 366.
# 11
# total simulation time =  197920.0 ps
# Setting iteration to iter 367.
# 11
# total simulation time =  198520.0 ps
# Setting iteration to iter 368.
# 11
# total simulation time =  199080.0 ps
# Setting iteration to iter 369.
# 11
# total simulation time =  199680.0 ps
# Setting iteration to iter 370.
# 11
# total simulation time =  200280.0 ps
# Setting iteration to iter 371.
# 11
# total simulation time =  200920.0 ps
# Setting iteration to iter 372.
# 11
# total simulation time =  201520.0 ps
# Setting iteration to iter 373.
# 11
# total simulation time =  202040.0 ps
# Setting iteration to iter 374.
# 11
# total simulation time =  202600.0 ps
# Setting iteration to iter 375.
# 11
# total simulation time =  203200.0 ps
# Setting iteration to iter 376.
# 11
# total simulation time =  203760.0 ps
# Setting iteration to iter 377.
# 11
# total simulation time =  204360.0 ps
# Setting iteration to iter 378.
# 11
# total simulation time =  205000.0 ps
# Setting iteration to iter 379.
# 11
# total simulation time =  205640.0 ps
# Setting iteration to iter 380.
# 11
# total simulation time =  206240.0 ps
# Setting iteration to iter 381.
# 11
# total simulation time =  206840.0 ps
# Setting iteration to iter 382.
# 11
# total simulation time =  207400.0 ps
# Setting iteration to iter 383.
# 11
# total simulation time =  207960.0 ps
# Setting iteration to iter 384.
# 11
# total simulation time =  208480.0 ps
# Setting iteration to iter 385.
# 11
# total simulation time =  209040.0 ps
# Setting iteration to iter 386.
# 11
# total simulation time =  209560.0 ps
# Setting iteration to iter 387.
# 11
# total simulation time =  210080.0 ps
# Setting iteration to iter 388.
# 11
# total simulation time =  210600.0 ps
# Setting iteration to iter 389.
# 11
# total simulation time =  211080.0 ps
# Setting iteration to iter 390.
# 11
# total simulation time =  211640.0 ps
# Setting iteration to iter 391.
# 11
# total simulation time =  212200.0 ps
# Setting iteration to iter 392.
# 11
# total simulation time =  212760.0 ps
# Setting iteration to iter 393.
# 11
# total simulation time =  213360.0 ps
# Setting iteration to iter 394.
# 11
# total simulation time =  213880.0 ps
# Setting iteration to iter 395.
# 11
# total simulation time =  214400.0 ps
# Setting iteration to iter 396.
# 11
# total simulation time =  214960.0 ps
# Setting iteration to iter 397.
# 11
# total simulation time =  215520.0 ps
# Setting iteration to iter 398.
# 11
# total simulation time =  216120.0 ps
# Setting iteration to iter 399.
# 11
# total simulation time =  216760.0 ps
# Setting iteration to iter 400.
# 11
# total simulation time =  217280.0 ps
# Setting iteration to iter 401.
# 11
# total simulation time =  217840.0 ps
# Setting iteration to iter 402.
# 11
# total simulation time =  218440.0 ps
# Setting iteration to iter 403.
# 11
# total simulation time =  219000.0 ps
# Setting iteration to iter 404.
# 11
# total simulation time =  219480.0 ps
# Setting iteration to iter 405.
# 11
# total simulation time =  219920.0 ps
# Setting iteration to iter 406.
# 11
# total simulation time =  220360.0 ps
# Setting iteration to iter 407.
# 11
# total simulation time =  220840.0 ps
# Setting iteration to iter 408.
# 11
# total simulation time =  221320.0 ps
# Setting iteration to iter 409.
# 11
# total simulation time =  221800.0 ps
# Setting iteration to iter 410.
# 11
# total simulation time =  222360.0 ps
# Setting iteration to iter 411.
# 11
# total simulation time =  222960.0 ps
# Setting iteration to iter 412.
# 11
# total simulation time =  223560.0 ps
# Setting iteration to iter 413.
# 11
# total simulation time =  224120.0 ps
# Setting iteration to iter 414.
# 11
# total simulation time =  224640.0 ps
# Setting iteration to iter 415.
# 11
# total simulation time =  225080.0 ps
# Setting iteration to iter 416.
# 11
# total simulation time =  225600.0 ps
# Setting iteration to iter 417.
# 11
# total simulation time =  226160.0 ps
# Setting iteration to iter 418.
# 11
# total simulation time =  226760.0 ps
# Setting iteration to iter 419.
# 11
# total simulation time =  227320.0 ps
# Setting iteration to iter 420.
# 11
# total simulation time =  227960.0 ps
# Setting iteration to iter 421.
# 11
# total simulation time =  228520.0 ps
# Setting iteration to iter 422.
# 11
# total simulation time =  229120.0 ps
# Setting iteration to iter 423.
# 11
# total simulation time =  229680.0 ps
# Setting iteration to iter 424.
# 11
# total simulation time =  230280.0 ps
# Setting iteration to iter 425.
# 11
# total simulation time =  230840.0 ps
# Setting iteration to iter 426.
# 11
# total simulation time =  231400.0 ps
# Setting iteration to iter 427.
# 11
# total simulation time =  231960.0 ps
# Setting iteration to iter 428.
# 11
# total simulation time =  232560.0 ps
# Setting iteration to iter 429.
# 11
# total simulation time =  233200.0 ps
# Setting iteration to iter 430.
# 11
# total simulation time =  233800.0 ps
# Setting iteration to iter 431.
# 11
# total simulation time =  234440.0 ps
# Setting iteration to iter 432.
# 11
# total simulation time =  235040.0 ps
# Setting iteration to iter 433.
# 11
# total simulation time =  235640.0 ps
# Setting iteration to iter 434.
# 11
# total simulation time =  236240.0 ps
# Setting iteration to iter 435.
# 11
# total simulation time =  236880.0 ps
# Setting iteration to iter 436.
# 11
# total simulation time =  237480.0 ps
# Setting iteration to iter 437.
# 11
# total simulation time =  238080.0 ps
# Setting iteration to iter 438.
# 11
# total simulation time =  238640.0 ps
# Setting iteration to iter 439.
# 11
# total simulation time =  239200.0 ps
# Setting iteration to iter 440.
# 11
# total simulation time =  239680.0 ps
# Setting iteration to iter 441.
# 11
# total simulation time =  240240.0 ps
# Setting iteration to iter 442.
# 11
# total simulation time =  240800.0 ps
# Setting iteration to iter 443.
# 11
# total simulation time =  241320.0 ps
# Setting iteration to iter 444.
# 11
# total simulation time =  241880.0 ps
# Setting iteration to iter 445.
# 11
# total simulation time =  242400.0 ps
# Setting iteration to iter 446.
# 11
# total simulation time =  243040.0 ps
# Setting iteration to iter 447.
# 11
# total simulation time =  243640.0 ps
# Setting iteration to iter 448.
# 11
# total simulation time =  244240.0 ps
# Setting iteration to iter 449.
# 11
# total simulation time =  244880.0 ps
# Setting iteration to iter 450.
# 11
# total simulation time =  245520.0 ps
# Setting iteration to iter 451.
# 11
# total simulation time =  246160.0 ps
# Setting iteration to iter 452.
# 11
# total simulation time =  246760.0 ps
# Setting iteration to iter 453.
# 11
# total simulation time =  247320.0 ps
# Setting iteration to iter 454.
# 11
# total simulation time =  247880.0 ps
# Setting iteration to iter 455.
# 11
# total simulation time =  248360.0 ps
# Setting iteration to iter 456.
# 11
# total simulation time =  248920.0 ps
# Setting iteration to iter 457.
# 11
# total simulation time =  249480.0 ps
# Setting iteration to iter 458.
# 11
# total simulation time =  249960.0 ps
# Setting iteration to iter 459.
# 11
# total simulation time =  250400.0 ps
# Setting iteration to iter 460.
# 11
# total simulation time =  250960.0 ps
# Setting iteration to iter 461.
# 11
# total simulation time =  251480.0 ps
# Setting iteration to iter 462.
# 11
# total simulation time =  252040.0 ps
# Setting iteration to iter 463.
# 11
# total simulation time =  252640.0 ps
# Setting iteration to iter 464.
# 11
# total simulation time =  253240.0 ps
# Setting iteration to iter 465.
# 11
# total simulation time =  253800.0 ps
# Setting iteration to iter 466.
# 11
# total simulation time =  254320.0 ps
# Setting iteration to iter 467.
# 11
# total simulation time =  254800.0 ps
# Setting iteration to iter 468.
# 11
# total simulation time =  255400.0 ps
# Setting iteration to iter 469.
# 11
# total simulation time =  256040.0 ps
# Setting iteration to iter 470.
# 11
# total simulation time =  256600.0 ps
# Setting iteration to iter 471.
# 11
# total simulation time =  257120.0 ps
# Setting iteration to iter 472.
# 11
# total simulation time =  257680.0 ps
# Setting iteration to iter 473.
# 11
# total simulation time =  258280.0 ps
# Setting iteration to iter 474.
# 11
# total simulation time =  258840.0 ps
# Setting iteration to iter 475.
# 11
# total simulation time =  259440.0 ps
# Setting iteration to iter 476.
# 11
# total simulation time =  260000.0 ps
# Setting iteration to iter 477.
# 11
# total simulation time =  260560.0 ps
# Setting iteration to iter 478.
# 11
# total simulation time =  261160.0 ps
# Setting iteration to iter 479.
# 11
# total simulation time =  261680.0 ps
# Setting iteration to iter 480.
# 11
# total simulation time =  262200.0 ps
# Setting iteration to iter 481.
# 11
# total simulation time =  262800.0 ps
# Setting iteration to iter 482.
# 11
# total simulation time =  263400.0 ps
# Setting iteration to iter 483.
# 11
# total simulation time =  264000.0 ps
# Setting iteration to iter 484.
# 11
# total simulation time =  264600.0 ps
# Setting iteration to iter 485.
# 11
# total simulation time =  265200.0 ps
# Setting iteration to iter 486.
# 11
# total simulation time =  265800.0 ps
# Setting iteration to iter 487.
# 11
# total simulation time =  266360.0 ps
# Setting iteration to iter 488.
# 11
# total simulation time =  266920.0 ps
# Setting iteration to iter 489.
# 11
# total simulation time =  267560.0 ps
# Setting iteration to iter 490.
# 11
# total simulation time =  268120.0 ps
# Setting iteration to iter 491.
# 11
# total simulation time =  268720.0 ps
# Setting iteration to iter 492.
# 11
# total simulation time =  269280.0 ps
# Setting iteration to iter 493.
# 11
# total simulation time =  269880.0 ps
# Setting iteration to iter 494.
# 11
# total simulation time =  270520.0 ps
# Setting iteration to iter 495.
# 11
# total simulation time =  271160.0 ps
# Setting iteration to iter 496.
# 11
# total simulation time =  271720.0 ps
# Setting iteration to iter 497.
# 11
# total simulation time =  272320.0 ps
# Setting iteration to iter 498.
# 11
# total simulation time =  272880.0 ps
# Setting iteration to iter 499.
# 11
# total simulation time =  273440.0 ps
# Setting iteration to iter 500.
# 11
# total simulation time =  273920.0 ps
# Setting iteration to iter 501.
# 11
# total simulation time =  274440.0 ps
# Setting iteration to iter 502.
# 11
# total simulation time =  274960.0 ps
# Setting iteration to iter 503.
# 11
# total simulation time =  275480.0 ps
# Setting iteration to iter 504.
# 11
# total simulation time =  275920.0 ps
# Setting iteration to iter 505.
# 11
# total simulation time =  276360.0 ps
# Setting iteration to iter 506.
# 11
# total simulation time =  276800.0 ps
# Setting iteration to iter 507.
# 11
# total simulation time =  277360.0 ps
# Setting iteration to iter 508.
# 11
# total simulation time =  277800.0 ps
# Setting iteration to iter 509.
# 11
# total simulation time =  278280.0 ps
# Setting iteration to iter 510.
# 11
# total simulation time =  278760.0 ps
# Setting iteration to iter 511.
# 11
# total simulation time =  279280.0 ps
# Setting iteration to iter 512.
# 11
# total simulation time =  279760.0 ps
# Setting iteration to iter 513.
# 11
# total simulation time =  280240.0 ps
# Setting iteration to iter 514.
# 11
# total simulation time =  280720.0 ps
# Setting iteration to iter 515.
# 11
# total simulation time =  281080.0 ps
# Setting iteration to iter 516.
# 11
# total simulation time =  281560.0 ps
# Setting iteration to iter 517.
# 11
# total simulation time =  282080.0 ps
# Setting iteration to iter 518.
# 11
# total simulation time =  282640.0 ps
# Setting iteration to iter 519.
# 11
# total simulation time =  283200.0 ps
# Setting iteration to iter 520.
# 11
# total simulation time =  283680.0 ps
# Setting iteration to iter 521.
# 11
# total simulation time =  284200.0 ps
# Setting iteration to iter 522.
# 11
# total simulation time =  284680.0 ps
# Setting iteration to iter 523.
# 11
# total simulation time =  285200.0 ps
# Setting iteration to iter 524.
# 11
# total simulation time =  285720.0 ps
# Setting iteration to iter 525.
# 11
# total simulation time =  286240.0 ps
# Setting iteration to iter 526.
# 11
# total simulation time =  286760.0 ps
# Setting iteration to iter 527.
# 11
# total simulation time =  287320.0 ps
# Setting iteration to iter 528.
# 11
# total simulation time =  287880.0 ps
# Setting iteration to iter 529.
# 11
# total simulation time =  288440.0 ps
# Setting iteration to iter 530.
# 11
# total simulation time =  289040.0 ps
# Setting iteration to iter 531.
# 11
# total simulation time =  289600.0 ps
# Setting iteration to iter 532.
# 11
# total simulation time =  290200.0 ps
# Setting iteration to iter 533.
# 11
# total simulation time =  290840.0 ps
# Setting iteration to iter 534.
# 11
# total simulation time =  291480.0 ps
# Setting iteration to iter 535.
# 11
# total simulation time =  292040.0 ps
# Setting iteration to iter 536.
# 11
# total simulation time =  292680.0 ps
# Setting iteration to iter 537.
# 11
# total simulation time =  293320.0 ps
# Setting iteration to iter 538.
# 11
# total simulation time =  293920.0 ps
# Setting iteration to iter 539.
# 11
# total simulation time =  294520.0 ps
# Setting iteration to iter 540.
# 11
# total simulation time =  295080.0 ps
# Setting iteration to iter 541.
# 11
# total simulation time =  295680.0 ps
# Setting iteration to iter 542.
# 11
# total simulation time =  296240.0 ps
# Setting iteration to iter 543.
# 11
# total simulation time =  296840.0 ps
# Setting iteration to iter 544.
# 11
# total simulation time =  297440.0 ps
# Setting iteration to iter 545.
# 11
# total simulation time =  298040.0 ps
# Setting iteration to iter 546.
# 11
# total simulation time =  298680.0 ps
# Setting iteration to iter 547.
# 11
# total simulation time =  299280.0 ps
# Setting iteration to iter 548.
# 11
# total simulation time =  299920.0 ps
# Setting iteration to iter 549.
# 11
# total simulation time =  300560.0 ps
# Setting iteration to iter 550.
# 11
# total simulation time =  301080.0 ps
# Setting iteration to iter 551.
# 11
# total simulation time =  301640.0 ps
# Setting iteration to iter 552.
# 11
# total simulation time =  302280.0 ps
# Setting iteration to iter 553.
# 11
# total simulation time =  302840.0 ps
# Setting iteration to iter 554.
# 11
# total simulation time =  303480.0 ps
# Setting iteration to iter 555.
# 11
# total simulation time =  304080.0 ps
# Setting iteration to iter 556.
# 11
# total simulation time =  304640.0 ps
# Setting iteration to iter 557.
# 11
# total simulation time =  305280.0 ps
# Setting iteration to iter 558.
# 11
# total simulation time =  305880.0 ps
# Setting iteration to iter 559.
# 11
# total simulation time =  306480.0 ps
# Setting iteration to iter 560.
# 11
# total simulation time =  307160.0 ps
# Setting iteration to iter 561.
# 11
# total simulation time =  307760.0 ps
# Setting iteration to iter 562.
# 11
# total simulation time =  308360.0 ps
# Setting iteration to iter 563.
# 11
# total simulation time =  309000.0 ps
# Setting iteration to iter 564.
# 11
# total simulation time =  309600.0 ps
# Setting iteration to iter 565.
# 11
# total simulation time =  310240.0 ps
# Setting iteration to iter 566.
# 11
# total simulation time =  310880.0 ps
# Setting iteration to iter 567.
# 11
# total simulation time =  311520.0 ps
# Setting iteration to iter 568.
# 11
# total simulation time =  312120.0 ps
# Setting iteration to iter 569.
# 11
# total simulation time =  312680.0 ps
# Setting iteration to iter 570.
# 11
# total simulation time =  313160.0 ps
# Setting iteration to iter 571.
# 11
# total simulation time =  313720.0 ps
# Setting iteration to iter 572.
# 11
# total simulation time =  314200.0 ps
# Setting iteration to iter 573.
# 11
# total simulation time =  314680.0 ps
# Setting iteration to iter 574.
# 11
# total simulation time =  315160.0 ps
# Setting iteration to iter 575.
# 11
# total simulation time =  315680.0 ps
# Setting iteration to iter 576.
# 11
# total simulation time =  316240.0 ps
# Setting iteration to iter 577.
# 11
# total simulation time =  316800.0 ps
# Setting iteration to iter 578.
# 11
# total simulation time =  317360.0 ps
# Setting iteration to iter 579.
# 11
# total simulation time =  317920.0 ps
# Setting iteration to iter 580.
# 11
# total simulation time =  318520.0 ps
# Setting iteration to iter 581.
# 11
# total simulation time =  318960.0 ps
# Setting iteration to iter 582.
# 11
# total simulation time =  319480.0 ps
# Setting iteration to iter 583.
# 11
# total simulation time =  320000.0 ps
# Setting iteration to iter 584.
# 11
# total simulation time =  320600.0 ps
# Setting iteration to iter 585.
# 11
# total simulation time =  321200.0 ps
# Setting iteration to iter 586.
# 11
# total simulation time =  321800.0 ps
# Setting iteration to iter 587.
# 11
# total simulation time =  322360.0 ps
# Setting iteration to iter 588.
# 11
# total simulation time =  322840.0 ps
# Setting iteration to iter 589.
# 11
# total simulation time =  323280.0 ps
# Setting iteration to iter 590.
# 11
# total simulation time =  323680.0 ps
# Setting iteration to iter 591.
# 11
# total simulation time =  324200.0 ps
# Setting iteration to iter 592.
# 11
# total simulation time =  324680.0 ps
# Setting iteration to iter 593.
# 11
# total simulation time =  325160.0 ps
# Setting iteration to iter 594.
# 11
# total simulation time =  325600.0 ps
# Setting iteration to iter 595.
# 11
# total simulation time =  326080.0 ps
# Setting iteration to iter 596.
# 11
# total simulation time =  326600.0 ps
# Setting iteration to iter 597.
# 11
# total simulation time =  327000.0 ps
# Setting iteration to iter 598.
# 11
# total simulation time =  327440.0 ps
# Setting iteration to iter 599.
# 11
# total simulation time =  327920.0 ps
# Setting iteration to iter 600.
# 11
# total simulation time =  328440.0 ps
# Setting iteration to iter 601.
# 11
# total simulation time =  329000.0 ps
# Setting iteration to iter 602.
# 11
# total simulation time =  329520.0 ps
# Setting iteration to iter 603.
# 11
# total simulation time =  330040.0 ps
# Setting iteration to iter 604.
# 11
# total simulation time =  330600.0 ps
# Setting iteration to iter 605.
# 11
# total simulation time =  331120.0 ps
# Setting iteration to iter 606.
# 11
# total simulation time =  331600.0 ps
# Setting iteration to iter 607.
# 11
# total simulation time =  332120.0 ps
# Setting iteration to iter 608.
# 11
# total simulation time =  332560.0 ps
# Setting iteration to iter 609.
# 11
# total simulation time =  333040.0 ps
# Setting iteration to iter 610.
# 11
# total simulation time =  333480.0 ps
# Setting iteration to iter 611.
# 11
# total simulation time =  333920.0 ps
# Setting iteration to iter 612.
# 11
# total simulation time =  334320.0 ps
# Setting iteration to iter 613.
# 11
# total simulation time =  334720.0 ps
# Setting iteration to iter 614.
# 11
# total simulation time =  335200.0 ps
# Setting iteration to iter 615.
# 11
# total simulation time =  335720.0 ps
# Setting iteration to iter 616.
# 11
# total simulation time =  336280.0 ps
# Setting iteration to iter 617.
# 11
# total simulation time =  336840.0 ps
# Setting iteration to iter 618.
# 11
# total simulation time =  337360.0 ps
# Setting iteration to iter 619.
# 11
# total simulation time =  337920.0 ps
# Setting iteration to iter 620.
# 11
# total simulation time =  338440.0 ps
# Setting iteration to iter 621.
# 11
# total simulation time =  339000.0 ps
# Setting iteration to iter 622.
# 11
# total simulation time =  339560.0 ps
# Setting iteration to iter 623.
# 11
# total simulation time =  340080.0 ps
# Setting iteration to iter 624.
# 11
# total simulation time =  340600.0 ps
# Setting iteration to iter 625.
# 11
# total simulation time =  341040.0 ps
# Setting iteration to iter 626.
# 11
# total simulation time =  341560.0 ps
# Setting iteration to iter 627.
# 11
# total simulation time =  342080.0 ps
# Setting iteration to iter 628.
# 11
# total simulation time =  342640.0 ps
# Setting iteration to iter 629.
# 11
# total simulation time =  343280.0 ps
# Setting iteration to iter 630.
# 11
# total simulation time =  343840.0 ps
# Setting iteration to iter 631.
# 11
# total simulation time =  344440.0 ps
# Setting iteration to iter 632.
# 11
# total simulation time =  345000.0 ps
# Setting iteration to iter 633.
# 11
# total simulation time =  345600.0 ps
# Setting iteration to iter 634.
# 11
# total simulation time =  346120.0 ps
# Setting iteration to iter 635.
# 11
# total simulation time =  346640.0 ps
# Setting iteration to iter 636.
# 11
# total simulation time =  347160.0 ps
# Setting iteration to iter 637.
# 11
# total simulation time =  347760.0 ps
# Setting iteration to iter 638.
# 11
# total simulation time =  348240.0 ps
# Setting iteration to iter 639.
# 11
# total simulation time =  348760.0 ps
# Setting iteration to iter 640.
# 11
# total simulation time =  349320.0 ps
# Setting iteration to iter 641.
# 11
# total simulation time =  349840.0 ps
# Setting iteration to iter 642.
# 11
# total simulation time =  350440.0 ps
# Setting iteration to iter 643.
# 11
# total simulation time =  350960.0 ps
# Setting iteration to iter 644.
# 11
# total simulation time =  351560.0 ps
# Setting iteration to iter 645.
# 11
# total simulation time =  352120.0 ps
# Setting iteration to iter 646.
# 11
# total simulation time =  352720.0 ps
# Setting iteration to iter 647.
# 11
# total simulation time =  353320.0 ps
# Setting iteration to iter 648.
# 11
# total simulation time =  353840.0 ps
# Setting iteration to iter 649.
# 11
# total simulation time =  354400.0 ps
# Setting iteration to iter 650.
# 11
# total simulation time =  354840.0 ps
# Setting iteration to iter 651.
# 11
# total simulation time =  355280.0 ps
# Setting iteration to iter 652.
# 11
# total simulation time =  355800.0 ps
# Setting iteration to iter 653.
# 11
# total simulation time =  356320.0 ps
# Setting iteration to iter 654.
# 11
# total simulation time =  356800.0 ps
# Setting iteration to iter 655.
# 11
# total simulation time =  357280.0 ps
# Setting iteration to iter 656.
# 11
# total simulation time =  357840.0 ps
# Setting iteration to iter 657.
# 11
# total simulation time =  358360.0 ps
# Setting iteration to iter 658.
# 11
# total simulation time =  358880.0 ps
# Setting iteration to iter 659.
# 11
# total simulation time =  359520.0 ps
# Setting iteration to iter 660.
# 11
# total simulation time =  360120.0 ps
# Setting iteration to iter 661.
# 11
# total simulation time =  360760.0 ps
# Setting iteration to iter 662.
# 11
# total simulation time =  361360.0 ps
# Setting iteration to iter 663.
# 11
# total simulation time =  361960.0 ps
# Setting iteration to iter 664.
# 11
# total simulation time =  362440.0 ps
# Setting iteration to iter 665.
# 11
# total simulation time =  362960.0 ps
# Setting iteration to iter 666.
# 11
# total simulation time =  363520.0 ps
# Setting iteration to iter 667.
# 11
# total simulation time =  364160.0 ps
# Setting iteration to iter 668.
# 11
# total simulation time =  364800.0 ps
# Setting iteration to iter 669.
# 11
# total simulation time =  365400.0 ps
# Setting iteration to iter 670.
# 11
# total simulation time =  366040.0 ps
# Setting iteration to iter 671.
# 11
# total simulation time =  366640.0 ps
# Setting iteration to iter 672.
# 11
# total simulation time =  367240.0 ps
# Setting iteration to iter 673.
# 11
# total simulation time =  367800.0 ps
# Setting iteration to iter 674.
# 11
# total simulation time =  368400.0 ps
# Setting iteration to iter 675.
# 11
# total simulation time =  369000.0 ps
# Setting iteration to iter 676.
# 11
# total simulation time =  369560.0 ps
# Setting iteration to iter 677.
# 11
# total simulation time =  370120.0 ps
# Setting iteration to iter 678.
# 11
# total simulation time =  370760.0 ps
# Setting iteration to iter 679.
# 11
# total simulation time =  371320.0 ps
# Setting iteration to iter 680.
# 11
# total simulation time =  371920.0 ps
# Setting iteration to iter 681.
# 11
# total simulation time =  372480.0 ps
# ...
# Setting iteration to iter 1129.
# 11
# total simulation time =  636360.0 ps
# Setting iteration to iter 1130.
# 11
# total simulation time =  637000.0 ps
# Setting iteration to iter 1131.
# 11
# total simulation time =  637600.0 ps
# Setting iteration to iter 1132.
# 11
# total simulation time =  638240.0 ps
# Setting iteration to iter 1133.
# 11
# total simulation time =  638880.0 ps
# Setting iteration to iter 1134.
# 11
# total simulation time =  639480.0 ps
# Setting iteration to iter 1135.
# 11
# total simulation time =  640080.0 ps
# Setting iteration to iter 1136.
# 11
# total simulation time =  640640.0 ps
# Setting iteration to iter 1137.
# 11
# total simulation time =  641240.0 ps
# Setting iteration to iter 1138.
# 11
# total simulation time =  641760.0 ps
# Setting iteration to iter 1139.
# 11
# total simulation time =  642320.0 ps
# Setting iteration to iter 1140.
# 11
# total simulation time =  642960.0 ps
# Setting iteration to iter 1141.
# 11
# total simulation time =  643520.0 ps
# Setting iteration to iter 1142.
# 11
# total simulation time =  644120.0 ps
# Setting iteration to iter 1143.
# 11
# total simulation time =  644760.0 ps
# Setting iteration to iter 1144.
# 11
# total simulation time =  645400.0 ps
# Setting iteration to iter 1145.
# 11
# total simulation time =  646000.0 ps
# Setting iteration to iter 1146.
# 11
# total simulation time =  646600.0 ps
# Setting iteration to iter 1147.
# 11
# total simulation time =  647280.0 ps
# Setting iteration to iter 1148.
# 11
# total simulation time =  647920.0 ps
# Setting iteration to iter 1149.
# 11
# total simulation time =  648480.0 ps
# Setting iteration to iter 1150.
# 11
# total simulation time =  649000.0 ps
# Setting iteration to iter 1151.
# 11
# total simulation time =  649560.0 ps
# Setting iteration to iter 1152.
# 11
# total simulation time =  650200.0 ps
# Setting iteration to iter 1153.
# 11
# total simulation time =  650840.0 ps
# Setting iteration to iter 1154.
# 11
# total simulation time =  651440.0 ps
# Setting iteration to iter 1155.
# 11
# total simulation time =  652080.0 ps
# Setting iteration to iter 1156.
# 11
# total simulation time =  652640.0 ps
# Setting iteration to iter 1157.
# 11
# total simulation time =  653280.0 ps
# Setting iteration to iter 1158.
# 11
# total simulation time =  653880.0 ps
# Setting iteration to iter 1159.
# 11
# total simulation time =  654560.0 ps
# Setting iteration to iter 1160.
# 11
# total simulation time =  655120.0 ps
# Setting iteration to iter 1161.
# 11
# total simulation time =  655760.0 ps
# Setting iteration to iter 1162.
# 11
# total simulation time =  656400.0 ps
# Setting iteration to iter 1163.
# 11
# total simulation time =  657000.0 ps
# Setting iteration to iter 1164.
# 11
# total simulation time =  657640.0 ps
# Setting iteration to iter 1165.
# 11
# total simulation time =  658320.0 ps
# Setting iteration to iter 1166.
# 11
# total simulation time =  659000.0 ps
# Setting iteration to iter 1167.
# 11
# total simulation time =  659680.0 ps
# Setting iteration to iter 1168.
# 11
# total simulation time =  660280.0 ps
# Setting iteration to iter 1169.
# 11
# total simulation time =  660920.0 ps
# Setting iteration to iter 1170.
# 11
# total simulation time =  661480.0 ps
# Setting iteration to iter 1171.
# 11
# total simulation time =  662120.0 ps
# Setting iteration to iter 1172.
# 11
# total simulation time =  662800.0 ps
# Setting iteration to iter 1173.
# 11
# total simulation time =  663400.0 ps
# Setting iteration to iter 1174.
# 11
# total simulation time =  664080.0 ps
# Setting iteration to iter 1175.
# 11
# total simulation time =  664720.0 ps
# Setting iteration to iter 1176.
# 11
# total simulation time =  665360.0 ps
# Setting iteration to iter 1177.
# 11
# total simulation time =  666000.0 ps
# Setting iteration to iter 1178.
# 11
# total simulation time =  666600.0 ps
# Setting iteration to iter 1179.
# 11
# total simulation time =  667200.0 ps
# Setting iteration to iter 1180.
# 11
# total simulation time =  667760.0 ps
# Setting iteration to iter 1181.
# 11
# total simulation time =  668360.0 ps
# Setting iteration to iter 1182.
# 11
# total simulation time =  668960.0 ps
# Setting iteration to iter 1183.
# 11
# total simulation time =  669520.0 ps
# Setting iteration to iter 1184.
# 11
# total simulation time =  670040.0 ps
# Setting iteration to iter 1185.
# 11
# total simulation time =  670680.0 ps
# Setting iteration to iter 1186.
# 11
# total simulation time =  671280.0 ps
# Setting iteration to iter 1187.
# 11
# total simulation time =  671920.0 ps
# Setting iteration to iter 1188.
# 11
# total simulation time =  672520.0 ps
# Setting iteration to iter 1189.
# 11
# total simulation time =  673080.0 ps
# Setting iteration to iter 1190.
# 11
# total simulation time =  673680.0 ps
# Setting iteration to iter 1191.
# 11
# total simulation time =  674360.0 ps
# Setting iteration to iter 1192.
# 11
# total simulation time =  675000.0 ps
# Setting iteration to iter 1193.
# 11
# total simulation time =  675680.0 ps
# Setting iteration to iter 1194.
# 11
# total simulation time =  676240.0 ps
# Setting iteration to iter 1195.
# 11
# total simulation time =  676720.0 ps
# Setting iteration to iter 1196.
# 11
# total simulation time =  677200.0 ps
# Setting iteration to iter 1197.
# 11
# total simulation time =  677720.0 ps
# Setting iteration to iter 1198.
# 11
# total simulation time =  678120.0 ps
# Setting iteration to iter 1199.
# 11
# total simulation time =  678560.0 ps
# Setting iteration to iter 1200.
# 11
# total simulation time =  679080.0 ps
# Setting iteration to iter 1201.
# 11
# total simulation time =  679600.0 ps
# Setting iteration to iter 1202.
# 11
# total simulation time =  680120.0 ps
# Setting iteration to iter 1203.
# 11
# total simulation time =  680600.0 ps
# Setting iteration to iter 1204.
# 11
# total simulation time =  681080.0 ps
# Setting iteration to iter 1205.
# 11
# total simulation time =  681560.0 ps
# Setting iteration to iter 1206.
# 11
# total simulation time =  682080.0 ps
# Setting iteration to iter 1207.
# 11
# total simulation time =  682560.0 ps
# Setting iteration to iter 1208.
# 11
# total simulation time =  683120.0 ps
# Setting iteration to iter 1209.
# 11
# total simulation time =  683720.0 ps
# Setting iteration to iter 1210.
# 11
# total simulation time =  684240.0 ps
# Setting iteration to iter 1211.
# 11
# total simulation time =  684760.0 ps
# Setting iteration to iter 1212.
# 11
# total simulation time =  685240.0 ps
# Setting iteration to iter 1213.
# 11
# total simulation time =  685720.0 ps
# Setting iteration to iter 1214.
# 11
# total simulation time =  686200.0 ps
# Setting iteration to iter 1215.
# 11
# total simulation time =  686680.0 ps
# Setting iteration to iter 1216.
# 11
# total simulation time =  687160.0 ps
# Setting iteration to iter 1217.
# 11
# total simulation time =  687720.0 ps
# Setting iteration to iter 1218.
# 11
# total simulation time =  688320.0 ps
# Setting iteration to iter 1219.
# 11
# total simulation time =  688920.0 ps
# Setting iteration to iter 1220.
# 11
# total simulation time =  689480.0 ps
# Setting iteration to iter 1221.
# 11
# total simulation time =  690040.0 ps
# Setting iteration to iter 1222.
# 11
# total simulation time =  690600.0 ps
# Setting iteration to iter 1223.
# 11
# total simulation time =  691160.0 ps
# Setting iteration to iter 1224.
# 11
# total simulation time =  691720.0 ps
# Setting iteration to iter 1225.
# 11
# total simulation time =  692280.0 ps
# Setting iteration to iter 1226.
# 11
# total simulation time =  692880.0 ps
# Setting iteration to iter 1227.
# 11
# total simulation time =  693400.0 ps
# Setting iteration to iter 1228.
# 11
# total simulation time =  694000.0 ps
# Setting iteration to iter 1229.
# 11
# total simulation time =  694560.0 ps
# Setting iteration to iter 1230.
# 11
# total simulation time =  695120.0 ps
# Setting iteration to iter 1231.
# 11
# total simulation time =  695680.0 ps
# Setting iteration to iter 1232.
# 11
# total simulation time =  696280.0 ps
# Setting iteration to iter 1233.
# 11
# total simulation time =  696960.0 ps
# Setting iteration to iter 1234.
# 11
# total simulation time =  697600.0 ps
# Setting iteration to iter 1235.
# 11
# total simulation time =  698200.0 ps
# Setting iteration to iter 1236.
# 11
# total simulation time =  698880.0 ps
# Setting iteration to iter 1237.
# 11
# total simulation time =  699480.0 ps
# Setting iteration to iter 1238.
# 11
# total simulation time =  700160.0 ps
# Setting iteration to iter 1239.
# 11
# total simulation time =  700800.0 ps
# Setting iteration to iter 1240.
# 11
# total simulation time =  701400.0 ps
# Setting iteration to iter 1241.
# 11
# total simulation time =  702080.0 ps
# Setting iteration to iter 1242.
# 11
# total simulation time =  702680.0 ps
# Setting iteration to iter 1243.
# 11
# total simulation time =  703200.0 ps
# Setting iteration to iter 1244.
# 11
# total simulation time =  703760.0 ps
# Setting iteration to iter 1245.
# 11
# total simulation time =  704280.0 ps
# Setting iteration to iter 1246.
# 11
# total simulation time =  704840.0 ps
# Setting iteration to iter 1247.
# 11
# total simulation time =  705320.0 ps
# Setting iteration to iter 1248.
# 11
# total simulation time =  705920.0 ps
# Setting iteration to iter 1249.
# 11
# total simulation time =  706520.0 ps
# Setting iteration to iter 1250.
# 11
# total simulation time =  707120.0 ps
# Setting iteration to iter 1251.
# 11
# total simulation time =  707640.0 ps
# Setting iteration to iter 1252.
# 11
# total simulation time =  708160.0 ps
# Setting iteration to iter 1253.
# 11
# total simulation time =  708680.0 ps
# Setting iteration to iter 1254.
# 11
# total simulation time =  709200.0 ps
# Setting iteration to iter 1255.
# 11
# total simulation time =  709720.0 ps
# Setting iteration to iter 1256.
# 11
# total simulation time =  710200.0 ps
# Setting iteration to iter 1257.
# 11
# total simulation time =  710640.0 ps
# Setting iteration to iter 1258.
# 11
# total simulation time =  711120.0 ps
# Setting iteration to iter 1259.
# 11
# total simulation time =  711680.0 ps
# Setting iteration to iter 1260.
# 11
# total simulation time =  712200.0 ps
# Setting iteration to iter 1261.
# 11
# total simulation time =  712760.0 ps
# Setting iteration to iter 1262.
# 11
# total simulation time =  713280.0 ps
# Setting iteration to iter 1263.
# 11
# total simulation time =  713800.0 ps
# Setting iteration to iter 1264.
# 11
# total simulation time =  714320.0 ps
# Setting iteration to iter 1265.
# 11
# total simulation time =  714760.0 ps
# Setting iteration to iter 1266.
# 11
# total simulation time =  715160.0 ps
# Setting iteration to iter 1267.
# 11
# total simulation time =  715560.0 ps
# Setting iteration to iter 1268.
# 11
# total simulation time =  716120.0 ps
# Setting iteration to iter 1269.
# 11
# total simulation time =  716680.0 ps
# Setting iteration to iter 1270.
# 11
# total simulation time =  717240.0 ps
# Setting iteration to iter 1271.
# 11
# total simulation time =  717880.0 ps
# Setting iteration to iter 1272.
# 11
# total simulation time =  718480.0 ps
# Setting iteration to iter 1273.
# 11
# total simulation time =  719120.0 ps
# Setting iteration to iter 1274.
# 11
# total simulation time =  719800.0 ps
# Setting iteration to iter 1275.
# 11
# total simulation time =  720400.0 ps
# Setting iteration to iter 1276.
# 11
# total simulation time =  721000.0 ps
# Setting iteration to iter 1277.
# 11
# total simulation time =  721600.0 ps
# Setting iteration to iter 1278.
# 11
# total simulation time =  722200.0 ps
# Setting iteration to iter 1279.
# 11
# total simulation time =  722880.0 ps
# Setting iteration to iter 1280.
# 11
# total simulation time =  723520.0 ps
# Setting iteration to iter 1281.
# 11
# total simulation time =  724200.0 ps
# Setting iteration to iter 1282.
# 11
# total simulation time =  724840.0 ps
# Setting iteration to iter 1283.
# 11
# total simulation time =  725480.0 ps
# Setting iteration to iter 1284.
# 11
# total simulation time =  726160.0 ps
# Setting iteration to iter 1285.
# 11
# total simulation time =  726840.0 ps
# Setting iteration to iter 1286.
# 11
# total simulation time =  727480.0 ps
# Setting iteration to iter 1287.
# 11
# total simulation time =  728160.0 ps
# Setting iteration to iter 1288.
# 11
# total simulation time =  728800.0 ps
# Setting iteration to iter 1289.
# 11
# total simulation time =  729480.0 ps
# Setting iteration to iter 1290.
# 11
# total simulation time =  730120.0 ps
# Setting iteration to iter 1291.
# 11
# total simulation time =  730760.0 ps
# Setting iteration to iter 1292.
# 11
# total simulation time =  731400.0 ps
# Setting iteration to iter 1293.
# 11
# total simulation time =  732080.0 ps
# Setting iteration to iter 1294.
# 11
# total simulation time =  732720.0 ps
# Setting iteration to iter 1295.
# 11
# total simulation time =  733400.0 ps
# Setting iteration to iter 1296.
# 11
# total simulation time =  734040.0 ps
# Setting iteration to iter 1297.
# 11
# total simulation time =  734640.0 ps
# Setting iteration to iter 1298.
# 11
# total simulation time =  735240.0 ps
# Setting iteration to iter 1299.
# 11
# total simulation time =  735920.0 ps
# Setting iteration to iter 1300.
# 11
# total simulation time =  736600.0 ps
# Setting iteration to iter 1301.
# 11
# total simulation time =  737240.0 ps
# Setting iteration to iter 1302.
# 11
# total simulation time =  737880.0 ps
# Setting iteration to iter 1303.
# 11
# total simulation time =  738480.0 ps
# Setting iteration to iter 1304.
# 11
# total simulation time =  739160.0 ps
# Setting iteration to iter 1305.
# 11
# total simulation time =  739760.0 ps
# Setting iteration to iter 1306.
# 11
# total simulation time =  740360.0 ps
# Setting iteration to iter 1307.
# 11
# total simulation time =  741040.0 ps
# Setting iteration to iter 1308.
# 11
# total simulation time =  741640.0 ps
# Setting iteration to iter 1309.
# 11
# total simulation time =  742240.0 ps
# Setting iteration to iter 1310.
# 11
# total simulation time =  742840.0 ps
# Setting iteration to iter 1311.
# 11
# total simulation time =  743440.0 ps
# Setting iteration to iter 1312.
# 11
# total simulation time =  744080.0 ps
# Setting iteration to iter 1313.
# 11
# total simulation time =  744720.0 ps
# Setting iteration to iter 1314.
# 11
# total simulation time =  745360.0 ps
# Setting iteration to iter 1315.
# 11
# total simulation time =  746000.0 ps
# Setting iteration to iter 1316.
# 11
# total simulation time =  746600.0 ps
# Setting iteration to iter 1317.
# 11
# total simulation time =  747080.0 ps
# Setting iteration to iter 1318.
# 11
# total simulation time =  747520.0 ps
# Setting iteration to iter 1319.
# 11
# total simulation time =  747920.0 ps
# Setting iteration to iter 1320.
# 11
# total simulation time =  748520.0 ps
# Setting iteration to iter 1321.
# 11
# total simulation time =  749080.0 ps
# Setting iteration to iter 1322.
# 11
# total simulation time =  749680.0 ps
# Setting iteration to iter 1323.
# 11
# total simulation time =  750320.0 ps
# Setting iteration to iter 1324.
# 11
# total simulation time =  750880.0 ps
# Setting iteration to iter 1325.
# 11
# total simulation time =  751480.0 ps
# Setting iteration to iter 1326.
# 11
# total simulation time =  752080.0 ps
# Setting iteration to iter 1327.
# 11
# total simulation time =  752640.0 ps
# Setting iteration to iter 1328.
# 11
# total simulation time =  753200.0 ps
# Setting iteration to iter 1329.
# 11
# total simulation time =  753720.0 ps
# Setting iteration to iter 1330.
# 11
# total simulation time =  754240.0 ps
# Setting iteration to iter 1331.
# 11
# total simulation time =  754640.0 ps
# Setting iteration to iter 1332.
# 11
# total simulation time =  755160.0 ps
# Setting iteration to iter 1333.
# 11
# total simulation time =  755720.0 ps
# Setting iteration to iter 1334.
# 11
# total simulation time =  756360.0 ps
# Setting iteration to iter 1335.
# 11
# total simulation time =  757000.0 ps
# Setting iteration to iter 1336.
# 11
# total simulation time =  757600.0 ps
# Setting iteration to iter 1337.
# 11
# total simulation time =  758200.0 ps
# Setting iteration to iter 1338.
# 11
# total simulation time =  758840.0 ps
# Setting iteration to iter 1339.
# 11
# total simulation time =  759480.0 ps
# Setting iteration to iter 1340.
# 11
# total simulation time =  760120.0 ps
# Setting iteration to iter 1341.
# 11
# total simulation time =  760680.0 ps
# Setting iteration to iter 1342.
# 11
# total simulation time =  761280.0 ps
# Setting iteration to iter 1343.
# 11
# total simulation time =  761920.0 ps
# Setting iteration to iter 1344.
# 11
# total simulation time =  762600.0 ps
# Setting iteration to iter 1345.
# 11
# total simulation time =  763200.0 ps
# Setting iteration to iter 1346.
# 11
# total simulation time =  763840.0 ps
# Setting iteration to iter 1347.
# 11
# total simulation time =  764480.0 ps
# Setting iteration to iter 1348.
# 11
# total simulation time =  765080.0 ps
# Setting iteration to iter 1349.
# 11
# total simulation time =  765680.0 ps
# Setting iteration to iter 1350.
# 11
# total simulation time =  766240.0 ps

# %%
plt.plot(1/time,'-r')
#plt.ylim(0,1200)
plt.xlabel('Iterations',fontsize=14)
plt.ylabel('Flux per unit time (ps$^{-1}$)',fontsize=14)
plt.title('CLN025 in explicit solvent',fontsize=14)
#plt.savefig('Flux_chig_exp.jpg',bbox_inches="tight",dpi = 300)
# Out:
# Text(0.5, 1.0, 'CLN025 in explicit solvent')

# %%
plt.yscale("log")
plt.plot(1/time,'-r',label="WE Simulation")
#plt.ylim(0,1200)
plt.xlabel('Iterations',fontsize=20)
plt.axhline(y = 1/(2.2*1000*1000),color = 'magenta',linestyle = '--',label="Unbiased Simulation")
plt.ylabel('Flux per unit time (ps$^{-1}$)',fontsize=20)
plt.legend(fontsize=14)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.title('CLN025 in explicit solvent',fontsize=20)
plt.savefig('Flux_chig_exp_log.jpg',bbox_inches="tight",dpi = 100)

# %%
print(time[-5:]/1000000)
# Out:
# [1.59256532 1.59374938 1.59493344 1.59611751 1.59730157]

# %%
from westpa.analysis import Run
run = Run.open("west.h5")
walker = max(run.recycled_walkers, key=lambda walker: walker.weight)
print(walker)
trace = walker.trace()
pcoords = []
for walker in trace:
    pcoords.append(walker.pcoords[1:])
pcoords = np.concatenate(pcoords)
time = np.zeros((len(pcoords),1))
i = 1
while(i<=len(pcoords)):
    time[i-1] = i*dt
    i = i + 1
#fig = plt.figure(figsize=(8, 6))
plt.plot(time[:]/1000,pcoords[:],'-b')
#plt.show()
plt.xlabel("simulation time of walker (ns)",fontsize=16)
#plt.ylabel("HLDA Coordinate",fontsize=16)
plt.axhline(y=1.6,color='r')
plt.axhline(y=0.28,color='g')
plt.title('CLN025 in explicit solvent',fontsize=16)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.savefig("ProgressCoordinate_explicit.jpg",bbox_inches="tight",dpi=100)
run.close()
run.h5file
# Out:
# Walker(22, Iteration(826, <WESTPA Run with 1350 iterations at 0x7f5909a4ebb0>))
# <Closed HDF5 file>

# %%
len(pcoords)
# Out:
# 8260

# %%
#Calculation of simulation time
from westpa.analysis import Run
run = Run.open("west.h5")
num_iter = run.num_iterations
resampling_time = 10 #in ps
st = np.zeros((num_iter,1))
i = 1
while(i<=num_iter):
    iter_current = run.iteration(i)
    num_walkers = iter_current.num_walkers
    st[i-1] = num_walkers*resampling_time
    i = i + 1
ST = sum(st)/1000
print('total simulation time = ',ST,"ns")
run.close()
run.h5file
# Out:
# total simulation time =  [766.24] ns
# <Closed HDF5 file>

# %%
from westpa.analysis import Run
run = Run.open("west.h5")
num_iter = run.num_iterations
n_walkers = np.zeros((num_iter,1))
iter_count = np.zeros((num_iter,1))
i = 1
while(i<=num_iter):
    iter_current = run.iteration(i)
    n_walkers[i-1,0] = iter_current.num_walkers
    iter_count[i-1,0] = i
    i = i + 1
plt.plot(iter_count[:],n_walkers[:],'-*',color="brown")
plt.xlabel("No. of iterations",fontsize=16)
plt.ylabel("No. of walkers",fontsize=16)
plt.title("CLN025 in explicit solvent",fontsize=16)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.savefig("w_dist_trial12_CE.jpg",bbox_inches="tight",dpi=100)

# %%
from westpa.analysis import Run
run = Run.open("west.h5")
num_iter = run.num_iterations
walker = run.recycled_walkers
i = 0
for w in walker:
    i = i + 1
print("No. of Recycled walkers is %d"%i)
# Out:
# No. of Recycled walkers is 1172
