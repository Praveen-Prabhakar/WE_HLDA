# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
data_d = np.loadtxt("HLDA_A")
data_end = np.loadtxt("END_DIST")

# %%
plt.plot(data_end[:,0]/200,data_end[:,1])
plt.ylabel("Distance (nm)")
plt.xlabel("time (ns)")
plt.ylim([0,2.7])
plt.title("Folded state simulation (End to End distance)")
plt.savefig("etoemis")

# %%
plt.plot(data_d[:,0]/200,data_d[:,1])
plt.xlabel("time(ns)")
plt.ylabel("d1 (nm)")
plt.title("d1 contact")
# Out:
# Text(0.5, 1.0, 'd1 contact')

# %%
plt.plot(data_d[:,0]/200,data_d[:,2])
plt.xlabel("time(ns)")
plt.ylabel("d2 (nm)")
plt.title("d2 contact")
# Out:
# Text(0.5, 1.0, 'd2 contact')

# %%
plt.plot(data_d[:,0]/200,data_d[:,3])
plt.xlabel("time(ns)")
plt.ylabel("d3 (nm)")
plt.title("d3 contact")
# Out:
# Text(0.5, 1.0, 'd3 contact')

# %%
plt.plot(data_d[:,0]/200,data_d[:,4])
plt.xlabel("time(ns)")
plt.ylabel("d4 (nm)")
plt.title("d4 contact")
# Out:
# Text(0.5, 1.0, 'd4 contact')

# %%
plt.plot(data_d[:,0]/200,data_d[:,5])
plt.xlabel("time(ns)")
plt.ylabel("d5 (nm)")
plt.title("d5 contact")
# Out:
# Text(0.5, 1.0, 'd5 contact')

# %%
plt.plot(data_d[:,0]/200,data_d[:,6])
plt.xlabel("time(ns)")
plt.ylabel("d6 (nm)")
plt.title("d6 contact")
# Out:
# Text(0.5, 1.0, 'd6 contact')

# %%
data_new = np.loadtxt("COLVAR_Fold_final")

# %%
plt.plot(data_new[:,0],data_new[:,1])

# %%
data_updated = np.loadtxt("hlda_updated")

# %%
plt.plot(data_updated[:,0],data_updated[:,1])
